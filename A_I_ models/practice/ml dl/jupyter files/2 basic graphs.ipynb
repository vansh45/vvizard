# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math as m

# %%
names =["radha","krishna","ram","sita","hanuman"]
marks=[21,34,56,73,12]
barlist =plt.bar(names,marks)   #barh for horizontal bar
barlist[2].set_color("red")
plt.show()

# %%
marks_maths =[30,12,65,78,87]
sns.lineplot(data = marks_maths, label = 'maths')
sns.lineplot(data = marks, label = 'english')
# Out:
# <AxesSubplot:>

# %%
plt.pie(marks , labels =names)
plt.show()

# %%
#sns.set()  for setting graph more attractive

# %%
sns.histplot(data=marks)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.kdeplot(data=marks, shade=True)
sns.set_style("whitegrid")

# %%
df = pd.DataFrame({'names':["radha","krishna","ram","sita","hanuman"],'marks_english':[21,34,56,73,12],'marks_maths':[30,12,65,78,87]})

# %%
df
# Out:
#      names  marks_english  marks_maths
# 0    radha             21           30
# 1  krishna             34           12
# 2      ram             56           65
# 3     sita             73           78
# 4  hanuman             12           87

# %%
# (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks" ---> sns.set_style("dark")

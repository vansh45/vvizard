# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_796/3841419929.py in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import numpy

# %%
! pip install geopandas
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\hp\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\hp\\AppData\\Local\\Temp\\pip-install-0tiw12kk\\fiona_10468991b5104f5291c21f375cb47184\\setup.py'"'"'; __file__='"'"'C:\\Users\\hp\\AppData\\Local\\Temp\\pip-install-0tiw12kk\\fiona_10468991b5104f5291c21f375cb47184\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\hp\AppData\Local\Temp\pip-pip-egg-info-p4cfd_7s'
#          cwd: C:\Users\hp\AppData\Local\Temp\pip-install-0tiw12kk\fiona_10468991b5104f5291c21f375cb47184\
#     Complete output (1 lines):
# ...

# %%
import folium

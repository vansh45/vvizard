# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
rc = pd.read_csv('adult_10k.csv')
rc
# Out:
#       Unnamed: 0  age         workclass  fnlwgt     education  \
# 0              0   25           Private  226802          11th
# 1              1   38           Private   89814       HS-grad
# 2              2   28         Local-gov  336951    Assoc-acdm
# 3              3   44           Private  160323  Some-college
# 4              4   18                 ?  103497  Some-college
# ...          ...  ...               ...     ...           ...
# 9995        9995   66  Self-emp-not-inc  176315     Bachelors
# 9996        9996   35           Private  187167       HS-grad
# 9997        9997   24           Private  241582  Some-college
# 9998        9998   31           Private  247328          11th
# 9999        9999   75  Self-emp-not-inc  157778     Assoc-voc
#
#       educational-num      marital-status         occupation   relationship  \
# 0                   7       Never-married  Machine-op-inspct      Own-child
# ...

# %%
rc.head()
# .tail for tail
# Out:
#    Unnamed: 0  age  workclass  fnlwgt     education  educational-num  \
# 0           0   25    Private  226802          11th                7
# 1           1   38    Private   89814       HS-grad                9
# 2           2   28  Local-gov  336951    Assoc-acdm               12
# 3           3   44    Private  160323  Some-college               10
# 4           4   18          ?  103497  Some-college               10
#
#        marital-status         occupation relationship   race  gender  \
# 0       Never-married  Machine-op-inspct    Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2  Married-civ-spouse    Protective-serv      Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4       Never-married                  ?    Own-child  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# ...

# %%
d = rc['age'].head(5)
d #series
# Out:
# 0    25
# 1    38
# 2    28
# 3    44
# 4    18
# Name: age, dtype: int64

# %%
e = rc[['age']].head(5)
e #dataframe
# Out:
#    age
# 0   25
# 1   38
# 2   28
# 3   44
# 4   18

# %%
f = rc[['age', 'education']].head(5)
f
# Out:
#    age     education
# 0   25          11th
# 1   38       HS-grad
# 2   28    Assoc-acdm
# 3   44  Some-college
# 4   18  Some-college

# %%
rc.iloc[-5:]
# rc.style.hide_index()
# Out:
#       Unnamed: 0  age         workclass  fnlwgt     education  \
# 9995        9995   66  Self-emp-not-inc  176315     Bachelors
# 9996        9996   35           Private  187167       HS-grad
# 9997        9997   24           Private  241582  Some-college
# 9998        9998   31           Private  247328          11th
# 9999        9999   75  Self-emp-not-inc  157778     Assoc-voc
#
#       educational-num      marital-status       occupation   relationship  \
# 9995               13            Divorced            Sales  Not-in-family
# 9996                9       Never-married     Adm-clerical      Unmarried
# 9997               10       Never-married            Sales  Not-in-family
# 9998                7  Married-civ-spouse  Protective-serv        Husband
# 9999               11            Divorced   Prof-specialty  Not-in-family
#
#        race  gender  capital-gain  capital-loss  hours-per-week  \
# 9995  White    Male           401             0              20
# ...

# %%
rc['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
rc.iloc[10:600,1]
# Out:
# 10     65
# 11     36
# 12     26
# 13     58
# 14     48
#        ..
# 595    59
# 596    38
# 597    50
# 598    51
# 599    22
# Name: age, Length: 590, dtype: int64

# %%
g = rc[['workclass','age']]
g.iloc[10:600:2]
# Out:
#         workclass  age
# 10        Private   65
# 12        Private   26
# 14        Private   48
# 16      State-gov   20
# 18        Private   37
# ..            ...  ...
# 590       Private   32
# 592     Local-gov   50
# 594       Private   49
# 596       Private   38
# 598  Self-emp-inc   51
#
# [295 rows x 2 columns]

# %%
rc['workclass'].value_counts()
# Out:
# Private             6843
# Self-emp-not-inc     813
# Local-gov            633
# ?                    603
# State-gov            444
# Self-emp-inc         369
# Federal-gov          290
# Without-pay            4
# Never-worked           1
# Name: workclass, dtype: int64

# %%
rc['workclass'][2]
# Out:
# 'Local-gov'

# %%
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       10000 non-null  int64
#  1   age              10000 non-null  int64
#  2   workclass        10000 non-null  object
#  3   fnlwgt           10000 non-null  int64
#  4   education        10000 non-null  object
#  5   educational-num  10000 non-null  int64
#  6   marital-status   10000 non-null  object
#  7   occupation       10000 non-null  object
#  8   relationship     10000 non-null  object
#  9   race             10000 non-null  object
#  10  gender           10000 non-null  object
#  11  capital-gain     10000 non-null  int64
#  12  capital-loss     10000 non-null  int64
#  13  hours-per-week   10000 non-null  int64
#  14  native-country   10000 non-null  object
#  15  income           10000 non-null  object
# dtypes: int64(7), object(9)
# ...

# %%
rc.drop(['Unnamed: 0'],axis =1,inplace =True)

# %%
rc.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
rc.describe()
# Out:
#                age        fnlwgt  educational-num  capital-gain  capital-loss  \
# count  10000.00000  1.000000e+04      10000.00000  10000.000000   10000.00000
# mean      38.75330  1.884136e+05         10.07380   1140.334400      88.72810
# std       13.87222  1.050463e+05          2.56975   8000.248482     405.44117
# min       17.00000  1.376900e+04          1.00000      0.000000       0.00000
# 25%       28.00000  1.157950e+05          9.00000      0.000000       0.00000
# 50%       37.00000  1.778355e+05         10.00000      0.000000       0.00000
# 75%       48.00000  2.375235e+05         12.00000      0.000000       0.00000
# max       90.00000  1.490400e+06         16.00000  99999.000000    3770.00000
#
#        hours-per-week
# count    10000.000000
# mean        40.462500
# std         12.416755
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
aa = rc.set_index("age")
aa
# Out:
#             workclass  fnlwgt     education  educational-num  \
# age
# 25            Private  226802          11th                7
# 38            Private   89814       HS-grad                9
# 28          Local-gov  336951    Assoc-acdm               12
# 44            Private  160323  Some-college               10
# 18                  ?  103497  Some-college               10
# ..                ...     ...           ...              ...
# 66   Self-emp-not-inc  176315     Bachelors               13
# 35            Private  187167       HS-grad                9
# 24            Private  241582  Some-college               10
# 31            Private  247328          11th                7
# 75   Self-emp-not-inc  157778     Assoc-voc               11
#
#          marital-status         occupation   relationship   race  gender  \
# age
# 25        Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
rc.iloc[1:3,0]
# Out:
# 1    38
# 2    28
# Name: age, dtype: int64

# %%
rc.loc[:,['workclass']]
# Out:
#              workclass
# 0              Private
# 1              Private
# 2            Local-gov
# 3              Private
# 4                    ?
# ...                ...
# 9995  Self-emp-not-inc
# 9996           Private
# 9997           Private
# 9998           Private
# 9999  Self-emp-not-inc
#
# [10000 rows x 1 columns]

# %%
#rc.loc[(rc.workclass)]  not valid

# %%
rc.loc[:,['age','race','gender']]
# Out:
#       age   race  gender
# 0      25  Black    Male
# 1      38  White    Male
# 2      28  White    Male
# 3      44  Black    Male
# 4      18  White  Female
# ...   ...    ...     ...
# 9995   66  White    Male
# 9996   35  White  Female
# 9997   24  White    Male
# 9998   31  White    Male
# 9999   75  White  Female
#
# [10000 rows x 3 columns]

# %%
df00 = rc.loc[(rc.race =='Black')& (rc.gender =='Female')].head(4)

df00.loc[:,['age','race','gender','workclass','relationship']]
# Out:
#      age   race  gender workclass   relationship
# 21    34  Black  Female   Private      Own-child
# 48    52  Black  Female   Private  Not-in-family
# 101   33  Black  Female   Private      Unmarried
# 131   24  Black  Female   Private      Unmarried

# %%
rc.loc[(rc.race == 'Black') & (rc.gender == 'Female')].loc[0:100]

# between index 0 and 100 refering to rc
# Out:
#     Unnamed: 0  age workclass  fnlwgt     education  educational-num  \
# 21          21   34   Private  238588  Some-college               10
# 48          48   52   Private  201062          11th                7
#
#    marital-status       occupation   relationship   race  gender  \
# 21  Never-married    Other-service      Own-child  Black  Female
# 48      Separated  Priv-house-serv  Not-in-family  Black  Female
#
#     capital-gain  capital-loss  hours-per-week native-country income
# 21             0             0              35  United-States  <=50K
# 48             0             0              18  United-States  <=50K

# %%
rc.loc[(rc.race == 'Black') & (rc.gender == 'Female')].iloc[0:100]

# between index 0 and 100 refering to general table ie first 100 in table
# Out:
#       Unnamed: 0  age  workclass  fnlwgt     education  educational-num  \
# 21            21   34    Private  238588  Some-college               10
# 48            48   52    Private  201062          11th                7
# 101          101   33    Private  202191  Some-college               10
# 131          131   24    Private  247846       HS-grad                9
# 151          151   27    Private  221561          11th                7
# ...          ...  ...        ...     ...           ...              ...
# 1959        1959   20    Private  139715       HS-grad                9
# 1969        1969   47    Private  219054       HS-grad                9
# 1975        1975   47  Local-gov  202606    Assoc-acdm               12
# 1981        1981   53  State-gov   94186    Assoc-acdm               12
# 2002        2002   65    Private  146159       7th-8th                4
#
#           marital-status       occupation   relationship   race  gender  \
# ...

# %%
rc.loc[(rc.race == 'Black') & (rc.gender == 'Female')&(rc['educational-num'] > 10),['native-country','education','educational-num']]
# Out:
#      native-country  education  educational-num
# 174   United-States    Masters               14
# 214   United-States  Bachelors               13
# 359   United-States  Bachelors               13
# 424   United-States  Assoc-voc               11
# 672   United-States  Bachelors               13
# ...             ...        ...              ...
# 9768  United-States    Masters               14
# 9776  United-States  Bachelors               13
# 9838  United-States  Bachelors               13
# 9842  United-States    Masters               14
# 9961  United-States  Bachelors               13
#
# [113 rows x 3 columns]

# %%
rc["workclass"].value_counts()
# Out:
# Private             6843
# Self-emp-not-inc     813
# Local-gov            633
# ?                    603
# State-gov            444
# Self-emp-inc         369
# Federal-gov          290
# Without-pay            4
# Never-worked           1
# Name: workclass, dtype: int64

# %%
for a in rc.columns:
    for i in range(len(rc[a])):
        if rc[a][i] =="?":
            rc[a][i] = np.nan     #cleaning data as ? symbol may create problems
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_1388/1385208931.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rc[a][i] = np.nan     #cleaning data as ? symbol may create problems

# %%
rc.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
rc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              10000 non-null  int64
#  1   workclass        9397 non-null   object
#  2   fnlwgt           10000 non-null  int64
#  3   education        10000 non-null  object
#  4   educational-num  10000 non-null  int64
#  5   marital-status   10000 non-null  object
#  6   occupation       9396 non-null   object
#  7   relationship     10000 non-null  object
#  8   race             10000 non-null  object
#  9   gender           10000 non-null  object
#  10  capital-gain     10000 non-null  int64
#  11  capital-loss     10000 non-null  int64
#  12  hours-per-week   10000 non-null  int64
#  13  native-country   9829 non-null   object
#  14  income           10000 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.1+ MB

# %%
rc.isna().sum()
# Out:
# age                  0
# workclass          603
# fnlwgt               0
# education            0
# educational-num      0
# marital-status       0
# occupation         604
# relationship         0
# race                 0
# gender               0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     171
# income               0
# dtype: int64

# %%
rc.dropna(axis =0,inplace =True)
rc.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
# ...

# %%
rc.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
rc.groupby("workclass").count()
# Out:
#                    age  fnlwgt  education  educational-num  marital-status  \
# workclass
# Federal-gov        283     283        283              283             283
# Local-gov          628     628        628              628             628
# Private           6728    6728       6728             6728            6728
# Self-emp-inc       364     364        364              364             364
# Self-emp-not-inc   797     797        797              797             797
# State-gov          433     433        433              433             433
# Without-pay          4       4          4                4               4
#
#                   occupation  relationship  race  gender  capital-gain  \
# workclass
# Federal-gov              283           283   283     283           283
# Local-gov                628           628   628     628           628
# Private                 6728          6728  6728    6728          6728
# ...

# %%
rc.groupby("workclass").age.count()
# Out:
# workclass
# Federal-gov          283
# Local-gov            628
# Private             6728
# Self-emp-inc         364
# Self-emp-not-inc     797
# State-gov            433
# Without-pay            4
# Name: age, dtype: int64

# %%
rc.groupby(['gender', 'race']).age.max()
# Out:
# gender  race
# Female  Amer-Indian-Eskimo    60
#         Asian-Pac-Islander    76
#         Black                 72
#         Other                 64
#         White                 85
# Male    Amer-Indian-Eskimo    75
#         Asian-Pac-Islander    90
#         Black                 81
#         Other                 65
#         White                 90
# Name: age, dtype: int64

# %%
rc.groupby("hours-per-week").age.min()   #age of youngest(on right) in each-hour-work group
# Out:
# hours-per-week
# 1     22
# 2     28
# 3     23
# 4     17
# 5     17
#       ..
# 90    26
# 92    41
# 96    23
# 98    33
# 99    29
# Name: age, Length: 87, dtype: int64

# %%
rc.groupby("workclass").mean()
# Out:
#                         age         fnlwgt  educational-num  capital-gain  \
# workclass
# Federal-gov       43.162544  183405.296820        10.756184   1221.416961
# Local-gov         41.197452  190427.877389        10.953822    641.146497
# Private           37.071790  191360.524673         9.874257    981.789982
# Self-emp-inc      44.673077  187391.480769        11.192308   5640.431319
# Self-emp-not-inc  45.568381  172907.138018        10.116688   1366.617315
# State-gov         39.424942  175942.357968        11.371824   1164.224018
# Without-pay       52.000000  148470.500000         8.500000      0.000000
#
#                   capital-loss  hours-per-week
# workclass
# Federal-gov         111.498233       41.901060
# Local-gov            75.165605       40.613057
# Private              86.859988       40.337247
# Self-emp-inc        144.670330       48.189560
# Self-emp-not-inc    106.005019       44.983689
# State-gov            80.570439       38.690531
# ...

# %%
gp = rc[['workclass','gender','age']]
gp_grp = gp.groupby(['workclass','gender'],as_index= False).mean()
gp_grp
# Out:
#            workclass  gender        age
# 0        Federal-gov  Female  41.294118
# 1        Federal-gov    Male  43.964646
# 2          Local-gov  Female  40.571984
# 3          Local-gov    Male  41.630728
# 4            Private  Female  35.968966
# 5            Private    Male  37.652223
# 6       Self-emp-inc  Female  42.577778
# 7       Self-emp-inc    Male  44.968652
# 8   Self-emp-not-inc  Female  45.214815
# 9   Self-emp-not-inc    Male  45.640483
# 10         State-gov  Female  38.274286
# 11         State-gov    Male  40.205426
# 12       Without-pay    Male  52.000000

# %%
# transpose of above
gp_pivot = gp_grp.pivot(index ='gender',columns ='workclass')
gp_pivot
# Out:
#                   age                                                      \
# workclass Federal-gov  Local-gov    Private Self-emp-inc Self-emp-not-inc
# gender
# Female      41.294118  40.571984  35.968966    42.577778        45.214815
# Male        43.964646  41.630728  37.652223    44.968652        45.640483
#
#
# workclass  State-gov Without-pay
# gender
# Female     38.274286         NaN
# Male       40.205426        52.0

# %%
# youngest employee in each race in each workclass
rc.groupby(['workclass', 'race']).apply(lambda df: df.loc[df.age.idxmin()])
# Out:
#                                      age         workclass  fnlwgt  \
# workclass        race
# Federal-gov      Amer-Indian-Eskimo   20       Federal-gov   26585
#                  Asian-Pac-Islander   32       Federal-gov   86150
#                  Black                21       Federal-gov  201815
#                  Other                47       Federal-gov  655066
#                  White                20       Federal-gov  244689
# Local-gov        Amer-Indian-Eskimo   17         Local-gov  161955
#                  Asian-Pac-Islander   20         Local-gov  298871
#                  Black                18         Local-gov  283342
#                  Other                27         Local-gov  118235
#                  White                17         Local-gov  292285
# Private          Amer-Indian-Eskimo   18           Private  102690
#                  Asian-Pac-Islander   18           Private  262118
#                  Black                17           Private   67444
# ...

# %%
rc.groupby("gender").mean()
# Out:
#               age         fnlwgt  educational-num  capital-gain  capital-loss  \
# gender
# Female  37.157110  184228.266821        10.109049    668.996023     61.250912
# Male    39.431029  190666.197106        10.121061   1444.026206    104.564469
#
#         hours-per-week
# gender
# Female       37.019887
# Male         42.981350

# %%
pd.crosstab(rc['workclass'],rc["race"])
# Out:
# race              Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# workclass
# Federal-gov                       10                  11     53      1    208
# Local-gov                         19                  11     86      3    509
# Private                           53                 172    618     62   5823
# Self-emp-inc                       0                   8     14      0    342
# Self-emp-not-inc                   6                  15     25      4    747
# State-gov                          6                  20     55      6    346
# Without-pay                        0                   0      0      0      4

# %%
rc.rename(columns = {'hours-per-week':'hrs_per_week'}, inplace = True)

# %%
rc.groupby(['workclass']).hrs_per_week.agg([len, min, max])
# Out:
#                    len  min  max
# workclass
# Federal-gov        283    4   99
# Local-gov          628    3   99
# Private           6728    1   99
# Self-emp-inc       364    6   99
# Self-emp-not-inc   797    1   99
# State-gov          433    4   99
# Without-pay          4   10   60

# %%
lenn = rc.groupby(['race','gender']).agg([max,min])

# %%
lenn = lenn.reset_index()
lenn
# Out:
#                  race  gender age        workclass                fnlwgt  \
#                               max min          max          min      max
# 0  Amer-Indian-Eskimo  Female  60  17    State-gov  Federal-gov   362775
# 1  Amer-Indian-Eskimo    Male  64  18    State-gov  Federal-gov   464621
# 2  Asian-Pac-Islander  Female  76  18    State-gov  Federal-gov   538193
# 3  Asian-Pac-Islander    Male  90  18    State-gov  Federal-gov   504423
# 4               Black  Female  72  18    State-gov  Federal-gov   884434
# 5               Black    Male  81  17    State-gov  Federal-gov   786418
# 6               Other  Female  64  17    State-gov      Private   414910
# 7               Other    Male  64  18    State-gov  Federal-gov   655066
# 8               White  Female  85  17    State-gov  Federal-gov  1047822
# 9               White    Male  90  17  Without-pay  Federal-gov  1490400
#
#              education        ... capital-gain     capital-loss      \
# ...

# %%
rc.sort_values(by = 'age', ascending = True)
# also sort in alphabetical order
# Out:
#       age         workclass  fnlwgt    education  educational-num  \
# 9434   17           Private   86019         11th                7
# 5291   17           Private  127366         10th                6
# 8380   17           Private  262031         12th                8
# 6562   17           Private  216137          9th                5
# 6932   17           Private  355559         12th                8
# ...   ...               ...     ...          ...              ...
# 7419   90  Self-emp-not-inc  122348  Prof-school               15
# 8982   90           Private  225063      HS-grad                9
# 8427   90       Federal-gov  311184      Masters               14
# 899    90           Private  149069   Assoc-acdm               12
# 6976   90           Private  250832      HS-grad                9
#
#           marital-status        occupation    relationship  \
# 9434       Never-married             Sales   Not-in-family
# ...

# %%
mean = rc['capital-gain'].mean()
new = rc['capital-gain'].map(lambda p: p + mean)

# %%
mean
# Out:
# 1190.884919346108

# %%
new
# Out:
# 0        1190.884919
# 1        1190.884919
# 2        1190.884919
# 3        8878.884919
# 5        1190.884919
#             ...
# 9995     1591.884919
# 9996     1190.884919
# 9997     1190.884919
# 9998     1190.884919
# 9999    17021.884919
# Name: capital-gain, Length: 9237, dtype: float64

# %%
mean = rc['capital-gain'].mean()
def remean_points(row):
    row['capital-gain'] = row['capital-gain'] + mean
    return row

rc.apply(remean_points, axis='columns')
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 0      25           Private  226802          11th                7
# 1      38           Private   89814       HS-grad                9
# 2      28         Local-gov  336951    Assoc-acdm               12
# 3      44           Private  160323  Some-college               10
# 5      34           Private  198693          10th                6
# ...   ...               ...     ...           ...              ...
# 9995   66  Self-emp-not-inc  176315     Bachelors               13
# 9996   35           Private  187167       HS-grad                9
# 9997   24           Private  241582  Some-college               10
# 9998   31           Private  247328          11th                7
# 9999   75  Self-emp-not-inc  157778     Assoc-voc               11
#
#           marital-status         occupation   relationship   race  gender  \
# 0          Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
sns.heatmap(rc.corr())
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
#from sklearn import linear_model
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\hp\Music\2023\Datasets\Jossa dataset\2020.csv')
df1
# Out:
#                                                Institute  \
# 0             Indian Institute of Technology Bhubaneswar
# 1             Indian Institute of Technology Bhubaneswar
# 2             Indian Institute of Technology Bhubaneswar
# 3             Indian Institute of Technology Bhubaneswar
# 4             Indian Institute of Technology Bhubaneswar
# ...                                                  ...
# 54603  North Eastern Regional Institute of Science an...
# 54604  North Eastern Regional Institute of Science an...
# 54605  North Eastern Regional Institute of Science an...
# 54606  North Eastern Regional Institute of Science an...
# 54607  North Eastern Regional Institute of Science an...
#
#                                    Academic Program Name Quota   Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# 1      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# ...

# %%
df1.Quota.unique()
# Out:
# array(['AI', 'HS', 'OS', 'GO', 'JK', 'LA'], dtype=object)

# %%
len(df1.Institute.value_counts().unique())
# Out:
# 104

# %%
df1['Seat Type'].unique()
# Out:
# array(['OPEN', 'OPEN (PwD)', 'EWS', 'OBC-NCL', 'SC', 'ST', 'EWS (PwD)',
#        'OBC-NCL (PwD)', 'SC (PwD)', 'ST (PwD)'], dtype=object)

# %%
df1['Seat Type'].isna().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# Institute                0
# Academic Program Name    0
# Quota                    0
# Seat Type                0
# Gender                   0
# Opening Rank             0
# Closing Rank             0
# Year                     0
# Round                    0
# dtype: int64

# %%
df1['Gender'].unique()
# Out:
# array(['Gender-Neutral', 'Female-only (including Supernumerary)'],
#       dtype=object)

# %%
df1.groupby('Gender')['Gender'].agg('count')
# Out:
# Gender
# Female-only (including Supernumerary)    20595
# Gender-Neutral                           34013
# Name: Gender, dtype: int64

# %%
len(df1['Academic Program Name'].unique())
# Out:
# 154

# %%
l =['Year','Opening Rank']

    
df2 = df1.drop(l,axis=1)

# %%
df2
# Out:
#                                                Institute  \
# 0             Indian Institute of Technology Bhubaneswar
# 1             Indian Institute of Technology Bhubaneswar
# 2             Indian Institute of Technology Bhubaneswar
# 3             Indian Institute of Technology Bhubaneswar
# 4             Indian Institute of Technology Bhubaneswar
# ...                                                  ...
# 54603  North Eastern Regional Institute of Science an...
# 54604  North Eastern Regional Institute of Science an...
# 54605  North Eastern Regional Institute of Science an...
# 54606  North Eastern Regional Institute of Science an...
# 54607  North Eastern Regional Institute of Science an...
#
#                                    Academic Program Name Quota   Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# 1      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# ...

# %%
dummies = pd.get_dummies(df1['Gender'],drop_first= True)
dummies.head(3)
# Out:
#    Gender-Neutral
# 0               1
# 1               0
# 2               1

# %%
df2 = pd.concat([df1,dummies],axis=1)

# %%
df2.drop(['Gender'],axis=1,inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df2['Quota_'] = le.fit_transform(df2['Quota'])

df2['Seat_Type'] = le.fit_transform(df2['Seat Type'])

# %%
df2
# Out:
#                                                Institute  \
# 0             Indian Institute of Technology Bhubaneswar
# 1             Indian Institute of Technology Bhubaneswar
# 2             Indian Institute of Technology Bhubaneswar
# 3             Indian Institute of Technology Bhubaneswar
# 4             Indian Institute of Technology Bhubaneswar
# ...                                                  ...
# 54603  North Eastern Regional Institute of Science an...
# 54604  North Eastern Regional Institute of Science an...
# 54605  North Eastern Regional Institute of Science an...
# 54606  North Eastern Regional Institute of Science an...
# 54607  North Eastern Regional Institute of Science an...
#
#                                    Academic Program Name Quota   Seat Type  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# 1      Civil Engineering (4 Years, Bachelor of Techno...    AI        OPEN
# ...

# %%
df2.drop(['Quota','Seat Type','Opening Rank','Year'],axis =1,inplace=True)
df2
# Out:
#                                                Institute  \
# 0             Indian Institute of Technology Bhubaneswar
# 1             Indian Institute of Technology Bhubaneswar
# 2             Indian Institute of Technology Bhubaneswar
# 3             Indian Institute of Technology Bhubaneswar
# 4             Indian Institute of Technology Bhubaneswar
# ...                                                  ...
# 54603  North Eastern Regional Institute of Science an...
# 54604  North Eastern Regional Institute of Science an...
# 54605  North Eastern Regional Institute of Science an...
# 54606  North Eastern Regional Institute of Science an...
# 54607  North Eastern Regional Institute of Science an...
#
#                                    Academic Program Name Closing Rank  Round  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...         8816      1
# 1      Civil Engineering (4 Years, Bachelor of Techno...        14366      1
# ...

# %%
df2[df2['Institute']=='Indian Institute of Technology Bhubaneswar']
# Out:
#                                         Institute  \
# 0      Indian Institute of Technology Bhubaneswar
# 1      Indian Institute of Technology Bhubaneswar
# 2      Indian Institute of Technology Bhubaneswar
# 3      Indian Institute of Technology Bhubaneswar
# 4      Indian Institute of Technology Bhubaneswar
# ...                                           ...
# 45746  Indian Institute of Technology Bhubaneswar
# 45747  Indian Institute of Technology Bhubaneswar
# 45748  Indian Institute of Technology Bhubaneswar
# 45749  Indian Institute of Technology Bhubaneswar
# 45750  Indian Institute of Technology Bhubaneswar
#
#                                    Academic Program Name Closing Rank  Round  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...         8816      1
# 1      Civil Engineering (4 Years, Bachelor of Techno...        14366      1
# 2      Civil Engineering (4 Years, Bachelor of Techno...          56P      1
# ...

# %%
df2[df2['Closing Rank'] =='56P']
# Out:
#                                         Institute  \
# 2      Indian Institute of Technology Bhubaneswar
# 9339   Indian Institute of Technology Bhubaneswar
# 18476  Indian Institute of Technology Bhubaneswar
# 27544  Indian Institute of Technology Bhubaneswar
#
#                                    Academic Program Name Closing Rank  Round  \
# 2      Civil Engineering (4 Years, Bachelor of Techno...          56P      1
# 9339   Civil Engineering (4 Years, Bachelor of Techno...          56P      2
# 18476  Civil Engineering (4 Years, Bachelor of Techno...          56P      3
# 27544  Civil Engineering (4 Years, Bachelor of Techno...          56P      4
#
#        Gender-Neutral  Quota_  Seat_Type
# 2                   1       0          5
# 9339                1       0          5
# 18476               1       0          5
# 27544               1       0          5

# %%
v=[]
for values in df2['Closing Rank']:
    if 'P' in values :
        v.append(values)

# %%
v
# Out:
# ['56P',
#  '242P',
#  '63P',
#  '131P',
#  '37P',
#  '51P',
#  '301P',
#  '250P',
#  '492P',
#  '238P',
#  '13P',
#  '85P',
#  '859P',
#  '32P',
#  '93P',
#  '80P',
#  '72P',
#  '290P',
#  '923P',
#  '226P',
#  '3P',
#  '178P',
#  '367P',
#  '33P',
#  '210P',
#  '549P',
#  '454P',
#  '225P',
#  '16P',
#  '14P',
#  '192P',
#  '306P',
#  '531P',
#  '154P',
#  '164P',
#  '137P',
#  '52P',
#  '43P',
#  '10P',
#  '9P',
#  '1P',
#  '765P',
#  '9P',
#  '643P',
#  '153P',
#  '1P',
#  '222P',
#  '555P',
#  '157P',
#  '912P',
#  '228P',
#  '6P',
#  '6P',
#  '15P',
#  '53P',
#  '302P',
#  '748P',
#  '86P',
#  '119P',
#  '370P',
#  '461P',
#  '753P',
#  '574P',
#  '1124P',
#  '220P',
#  '1111P',
#  '260P',
#  '472P',
#  '800P',
#  '139P',
#  '209P',
#  '638P',
#  '1201P',
#  '233P',
#  '85P',
#  '37P',
#  '4P',
#  '112P',
#  '361P',
#  '380P',
#  '652P',
#  '1207P',
#  '186P',
#  '489P',
#  '190P',
#  '208P',
#  '20P',
#  '34P',
#  '51P',
#  '229P',
#  '50P',
#  '10P',
#  '5P',
#  '124P',
# ...

# %%
for values in v:
    df2 = df2[~(df2['Closing Rank'] == values)]
#df2 = df2[~(df2['Closing Rank'] == '56P')]

# %%
df2['Closing Rank'] = df2['Closing Rank'].astype('int')

# %%
df2
# Out:
#                                                Institute  \
# 0             Indian Institute of Technology Bhubaneswar
# 1             Indian Institute of Technology Bhubaneswar
# 3             Indian Institute of Technology Bhubaneswar
# 4             Indian Institute of Technology Bhubaneswar
# 5             Indian Institute of Technology Bhubaneswar
# ...                                                  ...
# 54603  North Eastern Regional Institute of Science an...
# 54604  North Eastern Regional Institute of Science an...
# 54605  North Eastern Regional Institute of Science an...
# 54606  North Eastern Regional Institute of Science an...
# 54607  North Eastern Regional Institute of Science an...
#
#                                    Academic Program Name  Closing Rank  Round  \
# 0      Civil Engineering (4 Years, Bachelor of Techno...          8816      1
# 1      Civil Engineering (4 Years, Bachelor of Techno...         14366      1
# ...

# %%
df3 = df2

# %%
df3['Closing Rank'].dtype
# Out:
# dtype('int32')

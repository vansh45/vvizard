# %%
print('Hello Universe')
# Out:
# Hello Universe

# %%
i = 'abab'
print(sorted(i))
# Out:
# ['a', 'a', 'b', 'b']

# %%
print('h') 

def fib(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b

# print(list[int](fib(10)))
print(sum(list[int](fib(11112025))))
# Out:
# h

# %%
k = "Led the development of a modular GPU-powered Face Recognition Attendance System using DeepFace for embeddings, CNNs and Transfer Learning for identification, with YOLOv8 and OpenCV enabling real time logging, achieving 94% recognition accuracy.","Managed and optimized the Face Recognition Activity System’s data pipeline on AWS Cloud using RDS, S3 and Sagemaker, while performing exploratory data analysis and performance evaluations, improving system accuracy and reducing false positives by 45%.","Collaborated on enhancing the sports analytics app by integrating LangChain and LLM based assistants which improved the depth and speed of predictive insights for users based on player stats and match conditions, cutting manual analysis time by up to 95%.","Developed monitoring and evaluation workflows for production models using PySpark, Pandas, & PyTorch, tracking performance metrics over time, detecting data drift, and implementing retraining strategies to maintain high accuracy in real-world scenarios."

# %%
for i in k:
    print(len(i))
print(sum([len(i) for i in k])/len(k))
# Out:
# 244
# 251
# 255
# 253
# 250.75

# %%
j = "Collaborated with clients analyzing biometric attendance data using Excel, Matplotlib, and Seaborn; generated reports on late arrivals, breaks, peak hours, and trained deep learning models to classify employee patterns for actionable insights."
print(len(j))
# Out:
# 243

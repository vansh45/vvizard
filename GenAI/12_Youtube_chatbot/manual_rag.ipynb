# %%
# !pip uninstall youtube-transcript-api
# !pip install youtube-transcript-api
# Out:
# Found existing installation: youtube-transcript-api 1.2.4
# Uninstalling youtube-transcript-api-1.2.4:
#   Would remove:
#     /home/vvizard/anaconda3/envs/genai/bin/youtube_transcript_api
#     /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages/youtube_transcript_api-1.2.4.dist-info/*
#     /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages/youtube_transcript_api/*
# Proceed (Y/n)? ERROR: Operation cancelled by user
# ^C
# Requirement already satisfied: youtube-transcript-api in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (2026.1.4)

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

load_dotenv()
# Out:
# True

# %%
import youtube_transcript_api
print(youtube_transcript_api.__file__)

from importlib.metadata import version
print(version("youtube-transcript-api"))

# !pip install --upgrade youtube-transcript-api
# Out:
# /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages/youtube_transcript_api/__init__.py
# 1.2.4
# Requirement already satisfied: youtube-transcript-api in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from youtube-transcript-api) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages (from requests->youtube-transcript-api) (2026.1.4)

# %%
import youtube_transcript_api
print(youtube_transcript_api.__file__)
print(dir(youtube_transcript_api))
# Out:
# /home/vvizard/anaconda3/envs/genai/lib/python3.11/site-packages/youtube_transcript_api/__init__.py
# ['AgeRestricted', 'CookieError', 'CookieInvalid', 'CookiePathInvalid', 'CouldNotRetrieveTranscript', 'FailedToCreateConsentCookie', 'FetchedTranscript', 'FetchedTranscriptSnippet', 'InvalidVideoId', 'IpBlocked', 'NoTranscriptFound', 'NotTranslatable', 'PoTokenRequired', 'RequestBlocked', 'Transcript', 'TranscriptList', 'TranscriptsDisabled', 'TranslationLanguageNotAvailable', 'VideoUnavailable', 'VideoUnplayable', 'YouTubeDataUnparsable', 'YouTubeRequestFailed', 'YouTubeTranscriptApi', 'YouTubeTranscriptApiException', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_api', '_errors', '_settings', '_transcripts', 'proxies']

# %%
from youtube_transcript_api import YouTubeTranscriptApi

video_id = "wwSzpaTHyS8"

from langchain_community.document_loaders import YoutubeLoader

loader = YoutubeLoader.from_youtube_url(f"https://www.youtube.com/watch?v={video_id}", add_video_info=False)
transcript = loader.load()

# %%
transcript
# Out:
# [Document(metadata={'source': 'wwSzpaTHyS8'}, page_content='Do your past, present and future all exist\xa0\nright now? Are you watching this video,\xa0\xa0 being born and lying on your deathbed\xa0\nat this very moment? Surprisingly,\xa0\xa0 the answer could be yes. But how can that be?\xa0\nWhat does that even mean? How does time work? Imagine the universe like a child painting\xa0\npictures on paper. Each picture shows\xa0\xa0 everything that\'s happening in the universe\xa0\nin a single moment. With each new moment,\xa0\xa0 all kinds of things occur everywhere – people\xa0\nare born and die, galactic civilizations expand,\xa0\xa0 you miss the bus – and our universe-kid makes\xa0\na new picture that replaces the old one. In this way you get something like a movie –\xa0\nonly the moment we\'re in right now is real.\xa0\xa0 The past is what happened before, now\xa0\nit’s gone. The future is still to come\xa0\xa0 and hasn\'t been drawn yet. This is kind\xa0\nof how time feels, right? Each moment\xa0\xa0 being replaced by the next one. The past\xa0\nis far behind us, the future doesn’t exist. But what if time is something else? What if the universe-kid has already finished all\xa0\nits drawings and stacks them on top of each other?\xa0\xa0 This way we get a block – a block of time that\xa0\ncontains the whole history of the universe. All\xa0\xa0 moments that have ever existed or will ever exist.\xa0\nBut in this block, in this stack of moments,\xa0\xa0 the past, the present and the future are\xa0\nequally real and exist at the same time. This feels wrong – the only things\xa0\nthat we perceive as real are those\xa0\xa0 things happening now. How can the past\xa0\nand future be real right now? The problem\xa0\xa0 is that according to the theory of\xa0\nrelativity, they kind of have to be. Heavily simplified, relativity says\xa0\nthat time and space are not separated,\xa0\xa0 but one connected spacetime. When you move\xa0\nthrough space, you are also moving through\xa0\xa0 the block. This means time passes differently\xa0\nfor different people, depending on how they\xa0\xa0 move through space relative to each other. And\xa0\nthis also means that what someone perceives as\xa0\xa0 “now” is a certain cut along the block – a cut\xa0\nthat will depend on how fast they are moving. So what you think is “now” is really only your\xa0\nnow – there are many different “nows” in the\xa0\xa0 universe and all of them are equally real. This\xa0\nalso means there is no universal past or future. Ok. This is a lot – how does this work? Imagine three alien spaceships a million light\xa0\nyears away. The first one just hovers in space,\xa0\xa0 not moving relative to you. You\xa0\nboth experience the same “now”,\xa0\xa0 the same present. If you had a magical\xa0\ninstantaneous internet connection,\xa0\xa0 you could do a video call right\xa0\nnow and chat about alien things. The second spaceship is flying away from us at 30\xa0\nkm/s, about 3 times faster than a human rocket.\xa0\xa0 It is moving differently through the block of\xa0\ntime than you are, which means its “now” is\xa0\xa0 different from yours. With the magical internet,\xa0\nthe aliens can talk to your ancestors in 1924,\xa0\xa0 when humanity was discovering the\xa0\nfirst galaxies outside the Milky Way. The third spaceship wants to visit Earth\xa0\nand is flying towards you at 30 km/s,\xa0\xa0 moving at the opposite angle of the\xa0\nsecond ship through the block of time.\xa0\xa0 It experiences yet another “now” – with the\xa0\nmagical internet, the aliens can talk to your\xa0\xa0 descendants in the year 2124, when humanity\xa0\nhas already built cities on Mars and Venus. Ok, so we have three different “nows” – so\xa0\nwhich one is correct? Well, that’s the problem.\xa0\xa0 Relativity is based on one powerful principle\xa0\n– cosmic democracy: the fact that the point of\xa0\xa0 view of all observers in the universe is equally\xa0\nvalid. All those “nows” have to be equally real.\xa0\xa0 But ...

# %%
text = transcript[0].page_content

text = text.replace('\xa0', ' ')

text = ' '.join(text.split())

print(text[:500])
# Out:
# Do your past, present and future all exist right now? Are you watching this video, being born and lying on your deathbed at this very moment? Surprisingly, the answer could be yes. But how can that be? What does that even mean? How does time work? Imagine the universe like a child painting pictures on paper. Each picture shows everything that's happening in the universe in a single moment. With each new moment, all kinds of things occur everywhere – people are born and die, galactic civilization

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([text])

# %%
print(len(chunks))
print(len(chunks[1].page_content))
chunks[13]
# Out:
# 14
# 997
# Document(metadata={}, page_content="off an annual membership once their trial ends. Our shop has grown so much over the years, thanks to all of you! Now it’s time to move our precious products to a bigger warehouse! But should our tiny birbs really have to carry all those boxes? No! Help us out and grab a box in our biggest sale ever! But first, we'll give you a little tour: Here you can see how our posters are actually created. And this is how our enamel pins are made. But watch out – there are some pretty creepy and dangerous things in here as well! And this is where the deals are crafted. They will only be available for a short time and as long as supplies last, so head over to the shop now. The birds really appreciate your help!")

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = FAISS.from_documents(chunks, embeddings)
vector_store.index_to_docstore_id
# Out:
# {0: '434cbf49-4fac-4d54-aa07-29b7719793fc',
#  1: '7b0e830e-db41-4cac-bbdd-eb6368ea14ef',
#  2: '234ab2b0-e56a-42c9-92f7-e56e19ba302f',
#  3: 'c7695317-9877-4b4b-8c33-a8585422e259',
#  4: 'cc271936-18a0-4dec-8541-c60c16d10650',
#  5: 'bc29ee95-0edd-4741-9cd8-bcf3bc5687e2',
#  6: '51658a75-3ea9-4522-9649-d450aa5feda8',
#  7: 'b67d4aaa-fcd8-48f4-9d60-e96bcd0a010a',
#  8: 'ed483a51-a8cb-4ef9-ac1a-48a0a666f588',
#  9: '03fa4375-747d-4880-ac61-62819b674ec0',
#  10: '8f41af52-f02c-4ec1-b58d-29202526499c',
#  11: '3b93c436-8b4f-4f48-9e69-68be9524f498',
#  12: '4dedf4dd-0b17-4db5-9f27-033fc169abf2',
#  13: 'af17c64d-f1d4-4c0f-9444-9655dad5f8b1'}

# %%
vector_store.get_by_ids(['51658a75-3ea9-4522-9649-d450aa5feda8'])
# Out:
# [Document(id='51658a75-3ea9-4522-9649-d450aa5feda8', metadata={}, page_content='an illusion? Well… maybe. Maybe your free will is a mirage. And maybe you missing the bus was already predetermined at the Big Bang, so feel free to continue watching. Except...quantum stuff is ruining everything again. Quantum processes can’t be predicted, not even in principle. Not because we are silly and don’t know how to do it – according to quantum physics, quantum particles are intrinsically random. For example, if you have a radioactive atom, it could decay at any moment, in the next second or in the next million years. We can calculate the probability that it will decay tomorrow, but no oracle in the universe will ever be able to tell you with absolute certainty if it will do so or not. But quantum particles can change the world. Imagine a radioactive element randomly decays and causes a genetic mutation in a nearby mammal. And then many generations later that mutation has led to a weird mix of duck and mammal that makes no sense. Or the atom decays a day later and the weird')]

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x744b3ebfe390>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is Time')
# Out:
# [Document(id='8f41af52-f02c-4ec1-b58d-29202526499c', metadata={}, page_content="with a kind of growing block universe, where time passes and the future is open. So which is correct? What is real? The present? The past? Are the dinosaurs as real as you are right now? What do the aliens on the other corner of the universe think about all this? To be honest, no one knows. What we’ve learned are two possibilities to describe time, but they're not the only ones. Some scientists think that the idea of “now” only makes sense near you, but not in the universe as a whole. Others think that time itself doesn’t even exist – that the whole concept is an illusion of our human mind. And others think that time does exist, but that it's not a fundamental feature of the universe – rather, time may be something that emerges from a deeper level of reality, just like heat emerges from the motion of individual molecules or life emerges from the interactions of lifeless proteins. We could go on, but… aren’t you about to miss the bus? The concept of time is abstract and elusive,"),
#  Document(id='7b0e830e-db41-4cac-bbdd-eb6368ea14ef', metadata={}, page_content='of how time feels, right? Each moment being replaced by the next one. The past is far behind us, the future doesn’t exist. But what if time is something else? What if the universe-kid has already finished all its drawings and stacks them on top of each other? This way we get a block – a block of time that contains the whole history of the universe. All moments that have ever existed or will ever exist. But in this block, in this stack of moments, the past, the present and the future are equally real and exist at the same time. This feels wrong – the only things that we perceive as real are those things happening now. How can the past and future be real right now? The problem is that according to the theory of relativity, they kind of have to be. Heavily simplified, relativity says that time and space are not separated, but one connected spacetime. When you move through space, you are also moving through the block. This means time passes differently for different people, depending on'),
#  Document(id='3b93c436-8b4f-4f48-9e69-68be9524f498', metadata={}, page_content='from the motion of individual molecules or life emerges from the interactions of lifeless proteins. We could go on, but… aren’t you about to miss the bus? The concept of time is abstract and elusive, possibly beyond complete human comprehension. Fortunately, there’s a vast world of things we do understand about the universe that you can explore right now — thanks to our friends at Brilliant.org. Brilliant has thousands of bite-sized, hands-on lessons in science, math, technology, and beyond. Their latest course, “Introduction to Probability,” offers a practical guide to interpreting the world. You’ll master the tools of chance, risk and prediction while learning to model real-world situations and running simulations of everything from election results to who will win the next World Cup. They even have a lesson on “The Past and Future,” where you’ll explore how past outcomes may not reliably forecast future events in the ever-evolving tapestry of time. And since it’s always a good time'),
#  Document(id='434cbf49-4fac-4d54-aa07-29b7719793fc', metadata={}, page_content="Do your past, present and future all exist right now? Are you watching this video, being born and lying on your deathbed at this very moment? Surprisingly, the answer could be yes. But how can that be? What does that even mean? How does time work? Imagine the universe like a child painting pictures on paper. Each picture shows everything that's happening in the universe in a single moment. With each new moment, all kinds of things occur everywhere – people are born and die, galactic civilizations expand, you miss the bus – and our universe-kid makes a new picture that replaces the old one. In this way you get something like a movie – only the moment we're in right now is real. The past is what happened before, now it’s gone. The future is still to come and hasn't been drawn yet. This is kind of how time feels, right? Each moment being replaced by the next one. The past is far behind us, the future doesn’t exist. But what if time is something else? What if the universe-kid has already")]
